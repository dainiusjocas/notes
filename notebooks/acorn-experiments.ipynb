# %%
# %load_ext autoreload
# %autoreload 2
import mycode.vap as vap

# %%
# The goal is to have an index with 100k docs with an attribute of one indexed-dimensional tensor in HNSW.
# Then try various filtering variations from 0.01% to 10%.
# Try to experiment with recall characteristics. I want to find a region in HNSW that doesn't find anything, then increase some explorability parameters and try to get some recall.
# One other thing to show is that targetHits is respected.
#
